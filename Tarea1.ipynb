# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib

# %%
import pandas as pd
import io

df=pd.read_csv('Ventas_totales_supermercados.csv')
df.info()
df

# %%
#Filtro por objeto 
f1=df[df["indice_tiempo"]=="2017-02-01"]
f1
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 1    2017-02-01                    25994.2                    25223.4
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 1                2.599420e+07  2.574918e+07       245020.769
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 1               2.599420e+07  9.719067e+06     6.438494e+06      8.309150e+06
#
#    ...       almacen     panaderia       lacteos        carnes  \
# 1  ...  6.576625e+06  925618.61472  2.855640e+06  2.600084e+06
#
#    verduleria_fruteria  alimentos_preparados_rotiseria  \
# 1         1.026167e+06                    328288.69508
#
#    articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 1                   4.053284e+06                         672290.51653
#
#    electronicos_articulos_hogar         otros
# 1                  1.257662e+06  2.354085e+06
#
# [1 rows x 24 columns]

# %%
#Filas no consecutivas
#Filtro por filas
f2=df.iloc[[2,14,26,38,50,62],:]
f2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 2     2017-03-01                    27780.0                    26334.3
# 14    2018-03-01                    36531.3                    28846.7
# 26    2019-03-01                    51065.7                    24647.7
# 38    2020-03-01                    85778.0                    26996.7
# 50    2021-03-01                   107225.9                    24627.6
# 62    2022-03-01                   168982.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 2                 2.778001e+07  2.747223e+07     3.077778e+05
# 14                3.653129e+07  3.605541e+07     4.758783e+05
# 26                5.106569e+07  5.034778e+07     7.179116e+05
# 38                8.577803e+07  8.417488e+07     1.603156e+06
# 50                1.072259e+08  1.032432e+08     3.982669e+06
# 62                1.689825e+08  1.643211e+08     4.661395e+06
#
# ...

# %%
#Filas Rango
f3=df.iloc[24:36,:]
f3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 24    2019-01-01                    45433.6                    23888.7
# 25    2019-02-01                    44592.1                    22542.0
# 26    2019-03-01                    51065.7                    24647.7
# 27    2019-04-01                    49621.4                    23073.8
# 28    2019-05-01                    50778.3                    22852.1
# 29    2019-06-01                    54413.4                    23803.4
# 30    2019-07-01                    55044.5                    23580.1
# 31    2019-08-01                    59672.1                    24329.9
# 32    2019-09-01                    57885.3                    22144.7
# 33    2019-10-01                    66325.6                    24652.7
# 34    2019-11-01                    67943.7                    24270.7
# 35    2019-12-01                    83524.6                    29147.9
#
# ...

# %%
#columnas consecutivas
f4=df.iloc[:,6:11]
f4
# Out:
#     ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0                2.785887e+07  1.023010e+07     6.864575e+06
# 1                2.599420e+07  9.719067e+06     6.438494e+06
# 2                2.778001e+07  1.024444e+07     6.908523e+06
# 3                2.913427e+07  1.031263e+07     7.454252e+06
# 4                2.796900e+07  1.014761e+07     6.735747e+06
# ..                        ...           ...              ...
# 60               1.545171e+08  4.696260e+07     4.605365e+07
# 61               1.522026e+08  4.629096e+07     4.528358e+07
# 62               1.689825e+08  5.126208e+07     4.736436e+07
# 63               1.771481e+08  5.319000e+07     5.006397e+07
# 64               1.796392e+08  5.273811e+07     4.988679e+07
#
#     tarjetas_credito  otros_medios
# 0       9.047205e+06  1.716991e+06
# 1       8.309150e+06  1.527489e+06
# 2       8.845010e+06  1.782031e+06
# 3       9.458167e+06  1.909221e+06
# 4       9.220930e+06  1.864714e+06
# ...

# %%
#columnas NO consecutivas
f5=df.iloc[:,[1,4,6]]
f5
# Out:
#     ventas_precios_corrientes  salon_ventas  ventas_totales_medio_pago
# 0                     27858.9  2.759173e+07               2.785887e+07
# 1                     25994.2  2.574918e+07               2.599420e+07
# 2                     27780.0  2.747223e+07               2.778001e+07
# 3                     29134.3  2.882748e+07               2.913427e+07
# 4                     27969.0  2.756931e+07               2.796900e+07
# ..                        ...           ...                        ...
# 60                   154517.1  1.496976e+08               1.545171e+08
# 61                   152202.6  1.484065e+08               1.522026e+08
# 62                   168982.5  1.643211e+08               1.689825e+08
# 63                   177148.1  1.730038e+08               1.771481e+08
# 64                   179639.2  1.753585e+08               1.796392e+08
#
# [65 rows x 3 columns]

# %%
#comparación
f6=df.head()
f6

# %%
f6=df[df["ventas_totales_medio_pago"]>=30000]
f6
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     2017-01-01                    27858.9                    27477.3
# 1     2017-02-01                    25994.2                    25223.4
# 2     2017-03-01                    27780.0                    26334.3
# 3     2017-04-01                    29134.3                    27045.9
# 4     2017-05-01                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    2022-01-01                   154517.1                    25463.4
# 61    2022-02-01                   152202.6                    23802.1
# 62    2022-03-01                   168982.5                    24612.4
# 63    2022-04-01                   177148.1                    24140.5
# 64    2022-05-01                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#conectores logicos las 2
f7=df[(df["ventas_precios_corrientes"]>20000)&(df["ventas_precios_constantes"]>30000)]
f7
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 11    2017-12-01                    40766.3                    34084.5
# 23    2018-12-01                    57204.0                    31136.1
# 59    2021-12-01                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 11                4.076632e+07  4.032029e+07     4.460368e+05
# 23                5.720396e+07  5.645236e+07     7.515994e+05
# 59                1.839832e+08  1.788667e+08     5.116431e+06
#
#     ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 11               4.076632e+07  1.371031e+07     1.107010e+07
# 23               5.720396e+07  1.937298e+07     1.625221e+07
# 59               1.839832e+08  5.664003e+07     5.543219e+07
#
#     tarjetas_credito  ...       almacen     panaderia       lacteos  \
# 11      1.457601e+07  ...  9.667850e+06  1.346131e+06  3.684165e+06
# ...

# %%
#filtro o una u otras
f8=df[(df["tarjetas_debito"]>5000000)|(df["tarjetas_credito"]>500000000)]
f8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     2017-01-01                    27858.9                    27477.3
# 1     2017-02-01                    25994.2                    25223.4
# 2     2017-03-01                    27780.0                    26334.3
# 3     2017-04-01                    29134.3                    27045.9
# 4     2017-05-01                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    2022-01-01                   154517.1                    25463.4
# 61    2022-02-01                   152202.6                    23802.1
# 62    2022-03-01                   168982.5                    24612.4
# 63    2022-04-01                   177148.1                    24140.5
# 64    2022-05-01                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#filtro not negación
f9=df[~(df["Periodo"]>2006)&(df["Sexo"]=="Mujeres")]
f9

# %%
#Filtro de filas vs columnas 
f10=df.loc[["Puebla","Durango"], ["Poblacion_ocupada_en_la_industria_manufacturera"]]
f10

# %%
f9.to_csv("Entregable1.csv")
from google.colab import files
files.download("Entregable1.csv")
